# %%
from bs4 import BeautifulSoup
import pandas as pd
import re
import numpy as np
import time

# %%
with open("slack.html", "r") as f:
    contents=f.read()
    soup = BeautifulSoup(contents,'lxml')
    i=0
    col =['alert', 'date']
    data=pd.DataFrame(columns=col)
    
    for tag in soup.select("body>div"):
        data.loc[i,'alert']=tag.text
        if len(tag.text)<28:
            if ':' not in tag.text:
                data.loc[i,'date'] = tag.text
        i+=1
        
print(data.shape)
data.head(10)
# Out:
# (33208, 2)
#                                                alert                    date
# 0                                December 31st, 2019     December 31st, 2019
# 1  AlertManagerAPP  12:36 PM[FIRING:3]  in prodAl...                     NaN
# 2  AlertManagerAPP  12:41 PM[RESOLVED]  in prodAl...                     NaN
# 3  AlertManagerAPP  5:18 PM[FIRING:1] DeadMansSwi...                     NaN
# 4  AlertManagerAPP  11:23 PM[FIRING:1] DeadMansSw...                     NaN
# 5                             Wednesday, January 1st  Wednesday, January 1st
# 6
# 7  AlertManagerAPP  5:28 AM[FIRING:1] DeadMansSwi...                     NaN
# 8  Prometheus AlertsAPP  11:32 AM[Alerting] CPU a...                     NaN
# 9  AlertManagerAPP  11:33 AM[FIRING:1] DeadMansSw...                     NaN

# %%
for i in range(len(data)):
    if data.loc[i,'alert']=='':
        if data.loc[i,'date'] =='':
            data.drop([i], inplace=True)

# %%
data.index =np.arange(len(data))
print(data.shape)
data
# Out:
# (32943, 2)
#                                                    alert                 date
# 0                                    December 31st, 2019  December 31st, 2019
# 1      AlertManagerAPP  12:36 PM[FIRING:3]  in prodAl...                  NaN
# 2      AlertManagerAPP  12:41 PM[RESOLVED]  in prodAl...                  NaN
# 3      AlertManagerAPP  5:18 PM[FIRING:1] DeadMansSwi...                  NaN
# 4      AlertManagerAPP  11:23 PM[FIRING:1] DeadMansSw...                  NaN
# ...                                                  ...                  ...
# 32938  AlertManagerAPP  3:11 AM[FIRING:2]  inAlerts F...                  NaN
# 32939  AlertManagerAPP  3:21 AM[FIRING:1]  inAlerts F...                  NaN
# 32940  3:23[FIRING:1] DeadMansSwitch | Проверочное оп...                  NaN
# 32941  AlertManagerAPP  3:56 AM[FIRING:2]  inAlerts F...                  NaN
# 32942  4:01[FIRING:1]  inAlerts Firing: s0336_j: Virt...                  NaN
#
# [32943 rows x 2 columns]

# %%
for i in range(len(data)):
    if data.loc[i,'date'] is not np.nan:
        try:
            if data.loc[i+1,'date'] is np.nan:
                data.loc[i+1,'date']=data.loc[i,'date']
            elif data.loc[i+1, 'date'] is not np.nan:
                pass
        except:
            pass

# %%
print(data.shape)
data
# Out:
# (32943, 2)
#                                                    alert                 date
# 0                                    December 31st, 2019  December 31st, 2019
# 1      AlertManagerAPP  12:36 PM[FIRING:3]  in prodAl...  December 31st, 2019
# 2      AlertManagerAPP  12:41 PM[RESOLVED]  in prodAl...  December 31st, 2019
# 3      AlertManagerAPP  5:18 PM[FIRING:1] DeadMansSwi...  December 31st, 2019
# 4      AlertManagerAPP  11:23 PM[FIRING:1] DeadMansSw...  December 31st, 2019
# ...                                                  ...                  ...
# 32938  AlertManagerAPP  3:11 AM[FIRING:2]  inAlerts F...                Today
# 32939  AlertManagerAPP  3:21 AM[FIRING:1]  inAlerts F...                Today
# 32940  3:23[FIRING:1] DeadMansSwitch | Проверочное оп...                Today
# 32941  AlertManagerAPP  3:56 AM[FIRING:2]  inAlerts F...                Today
# 32942  4:01[FIRING:1]  inAlerts Firing: s0336_j: Virt...                Today
#
# [32943 rows x 2 columns]

# %%
for i in range(len(data)):
    if data.loc[i,'alert']==data.loc[i,'date']:
        data.drop([i], inplace=True)

# %%
data.index=np.arange(len(data))
print(data.shape)
data.head(10)
# Out:
# (32676, 2)
#                                                alert                    date
# 0  AlertManagerAPP  12:36 PM[FIRING:3]  in prodAl...     December 31st, 2019
# 1  AlertManagerAPP  12:41 PM[RESOLVED]  in prodAl...     December 31st, 2019
# 2  AlertManagerAPP  5:18 PM[FIRING:1] DeadMansSwi...     December 31st, 2019
# 3  AlertManagerAPP  11:23 PM[FIRING:1] DeadMansSw...     December 31st, 2019
# 4  AlertManagerAPP  5:28 AM[FIRING:1] DeadMansSwi...  Wednesday, January 1st
# 5  Prometheus AlertsAPP  11:32 AM[Alerting] CPU a...  Wednesday, January 1st
# 6  AlertManagerAPP  11:33 AM[FIRING:1] DeadMansSw...  Wednesday, January 1st
# 7  Prometheus AlertsAPP  11:37 AM[OK] CPU all hos...  Wednesday, January 1st
# 8  Prometheus AlertsAPP  12:22 PM[Alerting] Timel...  Wednesday, January 1st
# 9  12:23[OK] Timeline: $site alertGrafana v6.4.4 ...  Wednesday, January 1st

# %%
i=0
col=['alert','time', 'date']
df=pd.DataFrame(columns=col)
for i in range(len(data)):
    df.loc[i,'alert']=data.loc[i,'alert']
    i+=1
print(i)

i=0
for tag in soup.select(".c-timestamp__label"):
    df.loc[i,'time']=tag.text
    i+=1
print(i)

i=0
for i in range(len(data)):
    df.loc[i,'date'] = data.loc[i,'date']
    i+=1
print(i)
# Out:
# 32676
# 32676
# 32676

# %%
df.head(20)
# Out:
#                                                 alert      time  \
# 0   AlertManagerAPP  12:36 PM[FIRING:3]  in prodAl...  12:36 PM
# 1   AlertManagerAPP  12:41 PM[RESOLVED]  in prodAl...  12:41 PM
# 2   AlertManagerAPP  5:18 PM[FIRING:1] DeadMansSwi...   5:18 PM
# 3   AlertManagerAPP  11:23 PM[FIRING:1] DeadMansSw...  11:23 PM
# 4   AlertManagerAPP  5:28 AM[FIRING:1] DeadMansSwi...   5:28 AM
# 5   Prometheus AlertsAPP  11:32 AM[Alerting] CPU a...  11:32 AM
# 6   AlertManagerAPP  11:33 AM[FIRING:1] DeadMansSw...  11:33 AM
# 7   Prometheus AlertsAPP  11:37 AM[OK] CPU all hos...  11:37 AM
# 8   Prometheus AlertsAPP  12:22 PM[Alerting] Timel...  12:22 PM
# 9   12:23[OK] Timeline: $site alertGrafana v6.4.4 ...     12:23
# 10  12:23[OK] Timeline: $site alertGrafana v6.4.4 ...     12:23
# 11  12:23[OK] Timeline: $site alertGrafana v6.4.4 ...     12:23
# 12  12:23[OK] Timeline: $site alertGrafana v6.4.4 ...     12:23
# 13  12:23[OK] Timeline: $site alertGrafana v6.4.4 ...     12:23
# 14  Prometheus AlertsAPP  1:09 PM[Alerting] Timeli...   1:09 PM
# 15  1:10[OK] Timeline: $site alertGrafana v6.4.4 |...      1:10
# 16  Prometheus AlertsAPP  3:46 PM[Alerting] Timeli...   3:46 PM
# 17  3:47[OK] Timeline: $site alertGrafana v6.4.4 |...      3:47
# 18  3:47[OK] Timeline: $site alertGrafana v6.4.4 |...      3:47
# 19  3:47[OK] Timeline: $site alertGrafana v6.4.4 |...      3:47
#
#                       date
# 0      December 31st, 2019
# 1      December 31st, 2019
# 2      December 31st, 2019
# 3      December 31st, 2019
# 4   Wednesday, January 1st
# 5   Wednesday, January 1st
# 6   Wednesday, January 1st
# 7   Wednesday, January 1st
# 8   Wednesday, January 1st
# 9   Wednesday, January 1st
# 10  Wednesday, January 1st
# 11  Wednesday, January 1st
# 12  Wednesday, January 1st
# 13  Wednesday, January 1st
# 14  Wednesday, January 1st
# 15  Wednesday, January 1st
# 16  Wednesday, January 1st
# 17  Wednesday, January 1st
# 18  Wednesday, January 1st
# 19  Wednesday, January 1st

# %%
df=df.drop_duplicates()
df.index = np.arange(len(df))

print(df.shape)
df.head(20)
# Out:
# (24655, 3)
#                                                 alert      time  \
# 0   AlertManagerAPP  12:36 PM[FIRING:3]  in prodAl...  12:36 PM
# 1   AlertManagerAPP  12:41 PM[RESOLVED]  in prodAl...  12:41 PM
# 2   AlertManagerAPP  5:18 PM[FIRING:1] DeadMansSwi...   5:18 PM
# 3   AlertManagerAPP  11:23 PM[FIRING:1] DeadMansSw...  11:23 PM
# 4   AlertManagerAPP  5:28 AM[FIRING:1] DeadMansSwi...   5:28 AM
# 5   Prometheus AlertsAPP  11:32 AM[Alerting] CPU a...  11:32 AM
# 6   AlertManagerAPP  11:33 AM[FIRING:1] DeadMansSw...  11:33 AM
# 7   Prometheus AlertsAPP  11:37 AM[OK] CPU all hos...  11:37 AM
# 8   Prometheus AlertsAPP  12:22 PM[Alerting] Timel...  12:22 PM
# 9   12:23[OK] Timeline: $site alertGrafana v6.4.4 ...     12:23
# 10  Prometheus AlertsAPP  1:09 PM[Alerting] Timeli...   1:09 PM
# 11  1:10[OK] Timeline: $site alertGrafana v6.4.4 |...      1:10
# 12  Prometheus AlertsAPP  3:46 PM[Alerting] Timeli...   3:46 PM
# 13  3:47[OK] Timeline: $site alertGrafana v6.4.4 |...      3:47
# 14  AlertManagerAPP  5:38 PM[FIRING:1] DeadMansSwi...   5:38 PM
# 15  AlertManagerAPP  11:43 PM[FIRING:1] DeadMansSw...  11:43 PM
# 16  AlertManagerAPP  5:48 AM[FIRING:1] DeadMansSwi...   5:48 AM
# 17  Prometheus AlertsAPP  6:36 AM[Alerting] CPU al...   6:36 AM
# 18  6:37[OK] CPU all hosts alertGrafana v6.4.4 | J...      6:37
# 19  Prometheus AlertsAPP  11:32 AM[Alerting] CPU a...  11:32 AM
#
#                       date
# 0      December 31st, 2019
# 1      December 31st, 2019
# 2      December 31st, 2019
# 3      December 31st, 2019
# 4   Wednesday, January 1st
# 5   Wednesday, January 1st
# 6   Wednesday, January 1st
# 7   Wednesday, January 1st
# 8   Wednesday, January 1st
# 9   Wednesday, January 1st
# 10  Wednesday, January 1st
# 11  Wednesday, January 1st
# 12  Wednesday, January 1st
# 13  Wednesday, January 1st
# 14  Wednesday, January 1st
# 15  Wednesday, January 1st
# 16   Thursday, January 2nd
# 17   Thursday, January 2nd
# 18   Thursday, January 2nd
# 19   Thursday, January 2nd

# %%
df.to_csv('slack_half_year2020.csv')

# %%
df
# Out:
#                                                    alert      time  \
# 0      AlertManagerAPP  12:36 PM[FIRING:3]  in prodAl...  12:36 PM
# 1      AlertManagerAPP  12:41 PM[RESOLVED]  in prodAl...  12:41 PM
# 2      AlertManagerAPP  5:18 PM[FIRING:1] DeadMansSwi...   5:18 PM
# 3      AlertManagerAPP  11:23 PM[FIRING:1] DeadMansSw...  11:23 PM
# 4      AlertManagerAPP  5:28 AM[FIRING:1] DeadMansSwi...   5:28 AM
# ...                                                  ...       ...
# 32671                                                NaN       NaN
# 32672                                                NaN       NaN
# 32673                                                NaN       NaN
# 32674                                                NaN       NaN
# 32675                                                NaN       NaN
#
#                          date
# 0         December 31st, 2019
# 1         December 31st, 2019
# 2         December 31st, 2019
# 3         December 31st, 2019
# 4      Wednesday, January 1st
# ...                       ...
# 32671                   Today
# 32672                   Today
# 32673                   Today
# 32674                   Today
# 32675                   Today
#
# [32676 rows x 3 columns]

# %% [markdown]
# <h1>ДАЛЬШЕ ИДУТ ЭКСПЕРИМЕНТЫ ВЕСЬ ОСНОВНОЙ КОД ВЫШЕ</h1>

# %%
#inst=df[df['alert'].apply(lambda alert: 'INSTANCE' in alert)]

df.insert(loc=1,column ='ALERT RESULT', value=0)
df
# Out:
#       Unnamed: 0  ALERT RESULT  \
# 0              0             0
# 1              1             0
# 2             56             0
# 3             57             0
# 4             66             0
# ...          ...           ...
# 2239       24483             0
# 2240       24547             0
# 2241       24552             0
# 2242       24555             0
# 2243       24612             0
#
#                                                   alert      time  \
# 0     AlertManagerAPP  12:36 PM[FIRING:3]  in prodAl...  12:36 PM
# 1     AlertManagerAPP  12:41 PM[RESOLVED]  in prodAl...  12:41 PM
# 2     AlertManagerAPP  12:09 PM[FIRING:1] InstanceDo...  12:09 PM
# 3     AlertManagerAPP  12:14 PM[RESOLVED] InstanceDo...  12:14 PM
# 4     AlertManagerAPP  3:35 PM[FIRING:5]  in devAler...   3:35 PM
# ...                                                 ...       ...
# 2239  3:27[RESOLVED]  in prodAlerts Resolved: INSTAN...      3:27
# 2240  AlertManagerAPP  12:32 PM[FIRING:6]  in prodAl...  12:32 PM
# 2241  AlertManagerAPP  1:17 PM[FIRING:5]  in prodAle...   1:17 PM
# 2242  AlertManagerAPP  1:27 PM[RESOLVED]  in prodAle...   1:27 PM
# 2243  AlertManagerAPP  1:27 PM[RESOLVED]  in prodAle...   1:27 PM
#
#                      date
# 0     December 31st, 2019
# 1     December 31st, 2019
# 2     Sunday, January 5th
# 3     Sunday, January 5th
# 4     Sunday, January 5th
# ...                   ...
# 2239    Monday, July 27th
# 2240            Yesterday
# 2241            Yesterday
# 2242            Yesterday
# 2243                Today
#
# [2244 rows x 5 columns]

# %%
df.insert(loc=2,column ='TIME_UP', value=0)

for i in range(len(df)):
    if 'RESOLVED' in df.loc[i,'alert']:
        df.loc[i,'ALERT RESULT'] = 'RESOLVED'

# %%
for i in range(len(df)):
    if 'FIRI' in df.loc[i,'alert']:
        df.loc[i,'ALERT RESULT'] = 'INSTANCE DOWN'

# %%
df
# Out:
#       Unnamed: 0   ALERT RESULT  TIME_UP  \
# 0              0  INSTANCE DOWN        0
# 1              1       RESOLVED        0
# 2             56  INSTANCE DOWN        0
# 3             57       RESOLVED        0
# 4             66  INSTANCE DOWN        0
# ...          ...            ...      ...
# 2239       24483       RESOLVED        0
# 2240       24547  INSTANCE DOWN        0
# 2241       24552  INSTANCE DOWN        0
# 2242       24555       RESOLVED        0
# 2243       24612       RESOLVED        0
#
#                                                   alert      time  \
# 0     AlertManagerAPP  12:36 PM[FIRING:3]  in prodAl...  12:36 PM
# 1     AlertManagerAPP  12:41 PM[RESOLVED]  in prodAl...  12:41 PM
# 2     AlertManagerAPP  12:09 PM[FIRING:1] InstanceDo...  12:09 PM
# 3     AlertManagerAPP  12:14 PM[RESOLVED] InstanceDo...  12:14 PM
# 4     AlertManagerAPP  3:35 PM[FIRING:5]  in devAler...   3:35 PM
# ...                                                 ...       ...
# 2239  3:27[RESOLVED]  in prodAlerts Resolved: INSTAN...      3:27
# 2240  AlertManagerAPP  12:32 PM[FIRING:6]  in prodAl...  12:32 PM
# 2241  AlertManagerAPP  1:17 PM[FIRING:5]  in prodAle...   1:17 PM
# 2242  AlertManagerAPP  1:27 PM[RESOLVED]  in prodAle...   1:27 PM
# 2243  AlertManagerAPP  1:27 PM[RESOLVED]  in prodAle...   1:27 PM
#
#                      date
# 0     December 31st, 2019
# 1     December 31st, 2019
# 2     Sunday, January 5th
# 3     Sunday, January 5th
# 4     Sunday, January 5th
# ...                   ...
# 2239    Monday, July 27th
# 2240            Yesterday
# 2241            Yesterday
# 2242            Yesterday
# 2243                Today
#
# [2244 rows x 6 columns]

# %%
j=0
for i in range(len(df)):
    if df.loc[i,'ALERT RESULT'] == 'INSTANCE DOWN':
        if df.loc[i+1,'ALERT RESULT'] == 'RESOLVED':
            if df.loc[i,'alert'][40:60] in df.loc[i+1,'alert']:
                j+=1
                print('time_down:', df.loc[i+1,'time'],' - ',df.loc[i,'time'])  
                print(j)
# Out:
# time_down: 12:14 PM  -  12:09 PM
# 1
# time_down: 4:23  -  4:18 PM
# 2
# time_down: 1:27 PM  -  12:12 PM
# 3
# time_down: 2:35  -  2:30
# 4
# time_down: 6:15  -  5:55 PM
# 5
# time_down: 6:47 PM  -  6:17
# 6
# time_down: 4:27  -  3:42 PM
# 7
# time_down: 6:56 PM  -  6:46 PM
# 8
# time_down: 4:46 PM  -  3:01
# 9
# time_down: 2:48 PM  -  2:23
# 10
# time_down: 7:41 PM  -  3:18
# 11
# time_down: 11:47 AM  -  8:17 AM
# 12
# time_down: 11:58  -  11:53
# 13
# time_down: 6:39 PM  -  6:34 PM
# 14
# time_down: 11:19 AM  -  11:09 AM
# 15
# time_down: 1:44  -  1:39 PM
# 16
# time_down: 2:07  -  2:02 PM
# 17
# time_down: 12:11 PM  -  11:06 AM
# 18
# time_down: 9:07 AM  -  7:27
# 19
# time_down: 11:40  -  6:30 AM
# 20
# time_down: 11:10  -  11:05
# 21
# time_down: 4:50  -  4:45 PM
# 22
# time_down: 8:05 PM  -  5:10
# 23
# time_down: 12:05  -  11:50
# 24
# time_down: 8:09  -  7:49
# 25
# time_down: 3:01 PM  -  2:51 PM
# 26
# time_down: 3:31 PM  -  3:21
# 27
# time_down: 10:41  -  10:36
# 28
# time_down: 4:46 PM  -  3:51
# 29
# time_down: 11:11  -  11:06
# 30
# time_down: 12:26 PM  -  10:51 AM
# 31
# time_down: 5:04 PM  -  3:04
# 32
# time_down: 6:30  -  6:25 PM
# 33
# time_down: 7:06  -  7:01 AM
# 34
# time_down: 10:47  -  10:37
# 35
# time_down: 12:12  -  12:07
# 36
# time_down: 1:00  -  12:55
# 37
# time_down: 3:00  -  2:55
# 38
# time_down: 11:13  -  11:08
# 39
# time_down: 11:30  -  11:25
# 40
# time_down: 5:35  -  5:20 PM
# 41
# time_down: 1:04  -  12:54
# 42
# time_down: 6:25 PM  -  5:37
# 43
# time_down: 11:44 AM  -  11:09 AM
# 44
# time_down: 11:13 AM  -  11:08
# 45
# time_down: 5:45  -  5:40 PM
# 46
# time_down: 4:47  -  4:42 AM
# 47
# time_down: 10:41  -  10:36
# 48
# time_down: 10:59  -  10:54
# 49
# time_down: 11:22  -  9:32
# 50
# time_down: 11:44 PM  -  11:24
# 51
# time_down: 11:13  -  11:09
# 52
# time_down: 11:13  -  11:08
# 53
# time_down: 6:23  -  6:08
# 54
# time_down: 11:13  -  11:08
# 55
# time_down: 2:38 PM  -  12:08
# 56
# time_down: 4:06  -  4:01 PM
# 57
# time_down: 7:10  -  7:05
# 58
# time_down: 8:05  -  8:00
# 59
# time_down: 10:15 PM  -  9:50 PM
# 60
# time_down: 11:10  -  11:00 AM
# 61
# time_down: 3:35  -  3:20 PM
# 62
# time_down: 10:48  -  8:43 AM
# 63
# time_down: 11:15  -  11:10
# 64
# time_down: 12:34 AM  -  12:14 AM
# 65
# time_down: 4:39 AM  -  4:29 AM
# 66
# time_down: 6:24 AM  -  6:14 AM
# 67
# time_down: 9:39  -  9:34
# 68
# time_down: 1:24  -  1:04
# 69
# time_down: 1:28  -  1:23
# 70
# time_down: 6:06  -  6:01 AM
# 71
# time_down: 6:42  -  6:17
# 72
# time_down: 6:56  -  6:51 AM
# 73
# time_down: 7:07  -  7:02 AM
# 74
# time_down: 7:54  -  7:49 AM
# 75
# time_down: 8:50  -  8:45 AM
# 76
# time_down: 9:02  -  8:57
# 77
# time_down: 8:44 PM  -  6:49 PM
# 78
# time_down: 4:35 AM  -  4:00
# 79
# time_down: 5:10  -  5:05 PM
# 80
# time_down: 11:34 AM  -  9:49 AM
# 81
# time_down: 10:38  -  10:28
# 82
# time_down: 7:01  -  6:46 PM
# 83
# time_down: 4:51  -  4:46
# 84
# time_down: 12:45  -  12:40
# 85
# time_down: 4:01  -  3:46
# 86
# time_down: 5:49  -  5:24 PM
# 87
# time_down: 10:32  -  8:17
# 88
# time_down: 6:19  -  6:09
# 89
# time_down: 7:36  -  6:06
# 90
# time_down: 12:50  -  12:45
# 91
# time_down: 6:52 AM  -  6:42 AM
# 92
# time_down: 7:13 AM  -  7:03
# 93
# time_down: 10:44 AM  -  10:09 AM
# 94
# time_down: 10:38  -  10:28
# 95
# time_down: 11:31 AM  -  10:56
# 96
# time_down: 2:44 PM  -  1:19 PM
# 97
# time_down: 10:19 AM  -  6:09 AM
# 98
# time_down: 11:50  -  11:30 AM
# 99
# time_down: 12:27 PM  -  12:12 PM
# 100
# time_down: 7:37 PM  -  6:28 PM
# 101
# time_down: 2:40  -  2:35 AM
# 102
# time_down: 11:52 AM  -  10:09 AM
# 103
# time_down: 10:25  -  10:20
# 104
# time_down: 10:39  -  10:34
# 105
# time_down: 4:53 PM  -  4:38
# 106
# time_down: 8:34 PM  -  8:19
# 107
# time_down: 8:54  -  8:49 PM
# 108
# time_down: 4:49 PM  -  4:39
# 109
# time_down: 11:49 AM  -  11:34
# 110
# time_down: 3:49 PM  -  3:29 PM
# 111
# time_down: 12:55  -  11:50 AM
# 112
# time_down: 11:55 AM  -  11:50
# 113
# time_down: 10:30  -  10:05
# 114
# time_down: 7:50 PM  -  4:10 PM
# 115
# time_down: 7:33  -  7:23 PM
# 116
# time_down: 8:30 PM  -  8:05 PM
# 117
# time_down: 3:17 PM  -  3:07 PM
# 118
# time_down: 11:32 AM  -  11:27
# 119
# time_down: 2:02  -  1:52 PM
# 120
# time_down: 3:02 PM  -  2:47
# 121
# time_down: 11:47 AM  -  8:27 AM
# 122
# time_down: 3:27  -  3:02
# 123
